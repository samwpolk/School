# %%
import tensorflow as tf
import datetime, os
# %load_ext tensorboard

# %%
stamp = '-'
logdir = 'logs/func/%s' % stamp
writer = tf.summary.create_file_writer(logdir)

# %%
x_data = np.array([
[0,0],[1,0],[0,1],[1,1]
])

y_data = np.array([
[0],[1],[1],[0]
])


#####################################
# Layer 1
#


W1 = tf.constant([[-4., -6., -5.],[ 3., 6., 4.]])
print(W1.shape)
print(W1)

###################################################
b1 = tf.constant([[-2., 3., -2.]])
print(b1.shape)
print(b1)

#####################################################
outputH1 = tf.linalg.matmul(inputData, W1) + b1
print(outputH1.shape)

print(outputH1)

outputH1_Activation = tf.sigmoid(tf.cast(outputH1, tf.float32))
print(outputH1_Activation.shape)

print(outputH1_Activation)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.ioff()
for i in range(3):
    plt.plot(np.random.rand(10))
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


path='/Users/swp/Downloads/ca_doj_deaths_in_custody_raw_1980-2015_05-14-2016.csv'
df = pd.read_csv(filepath_or_buffer=path)

r, c = df.shape

print(df.head())

print(df.tail())

print(df.shape)

print(df.info())

#df.hist(xrot=-45, figsize=(20, 20))x
x = df['race'][]


x1 = range(0,r)
print(c)
plt.scatter(df['date_of_death_yyyy'],df['county'])
# Out:
#   File "<ipython-input-48-61f2f657dc46>", line 19
#     x = df['race'][]
#                    ^
# SyntaxError: invalid syntax

# %%
x1 = range(0,r)
print(c)
plt.scatter(x1,df['county'])
# Out:
# 21
